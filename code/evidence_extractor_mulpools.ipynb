# %%
import os
import re
import itertools
import pandas as pd
import numpy as np
import glob
import time
import datetime
import multiprocessing
import concurrent.futures

# %%
# Extracts evidence from a text
def get_evidence_from_text(text, evi_types=['url']):
    target_list=['ip','url']   
    assert set(evi_types).issubset(set(target_list)), "can't find evience types."
    
    df_list=[]
    for type in evi_types:     
        if type.lower() == 'url':
            # Define the regular expression pattern to match URLs
            pattern = r"\b(?:https?://)(?:www\.)?(?:\w+)(?:\.\w+)+(?:/[^/\s\"\'<>{}]*)*\b"
            
        if type.lower() == 'ip':
            # Extracts the ip from text file
            # IPv4 address in the form of a string of four decimal numbers separated by periods. 
            # Each decimal number in the range of 0 to 255.
            # pattern = r"\b(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\b" 
            pattern =r'(\d{1,3}\.){3}\d{1,3}'
        rows=[(match.start(), match.end()-1, match.group()) 
                            for match in re.finditer(pattern , text)]   
        starts, ends, strs = zip(*rows) if len(rows) > 0 else ([], [], [])
        pd_type = pd.DataFrame({'type': type, 'value': strs, 'start_pos': starts, 'end_pos': ends})
        df_list.append(pd_type)
    return  pd.concat(df_list,ignore_index=True) 


# Extracts evidence from line of a file
def get_evidence_from_line(file_id, text, line_num, evi_types=['url']):
    df=get_evidence_from_text(text, evi_types)
    df['file_id']=file_id
    df['text']=text.rstrip() 
    df['line_num']=line_num
    return df

#Extracts evidence from file
def get_evidence_from_file(file, evi_types=['url']):
    try:    
         with open(file, 'r', encoding="utf8") as f:
            lines = f.readlines()
            # skip if a file is empty
            if len(lines)>0 :
                return pd.concat([get_evidence_from_line(file, line, i, evi_types) 
                          for i, line in enumerate(lines)]) 
            else:
                return None
    except UnicodeDecodeError as e:
        print(f"Error decoding file: {e} : {file}")
        
# Extracts evidence from a directory recursively. Save the results to a file
# The default directory of the output is output folder 
def get_evidence_from_folder(directory, evi_types=['url'], of_prefix="evi", support_threads=True, save=True):
    print(f'processing {directory} and # of files/directories in the directory is {len(os.listdir(directory))}' )
    start_time = time.time()
    
    # Processing all files recursively
    all_files = glob.glob(directory+"/**", recursive=True)
    all_files = [f for f in all_files if not os.path.isdir(f)]  
    
    if support_threads: 
        num_threads = multiprocessing.cpu_count()  
        with concurrent.futures.ThreadPoolExecutor(max_workers=num_threads) as executor:
            # Process the files in parallel
            df=pd.concat([executor.submit(get_evidence_from_file, filename,  evi_types).result() 
                for filename in all_files]).reset_index().drop('index', axis=1)
    else:
        df= pd.concat([get_evidence_from_file(filename, evi_types) 
                      for filename in all_files]).reset_index().drop('index', axis=1)
    
    end_time = time.time()
    computing_time = end_time - start_time
    print(f"Computing time: {computing_time:.2f} seconds")
    
    if save:           
        # Save the DataFrame to a CSV file
        folder_path = "./output/"
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        
        current_time = datetime.datetime.now()
        file_name = of_prefix+"_"+ re.sub(r'[^\w\s]+', '-', directory)+"_".join(evi_types)+\
            "_"+current_time.strftime("%Y-%m-%d_%H-%M-%S.csv")
        of = folder_path + file_name
        
        df.to_csv(of, encoding="utf8", index=False)
        
        print(f"The results are saved to a default folder {of}")
    return df

# %%
get_evidence_from_folder("E:/vmshared_storage/Kali202004/bin2text/", evi_types=['ip'], of_prefix="xu_simple")
# Out:
# processing E:/vmshared_storage/Kali202004/bin2text/ and # of files/directories in the directory is 6
# Error decoding file: 'utf-8' codec can't decode byte 0xe9 in position 37: invalid continuation byte : E:/vmshared_storage/Kali202004/bin2text\txt\01336019a63a42c53f5b898a620f431953fe06c2.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x82 in position 7: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\02207641b1193afa96eee2f59b58d86c752f57ee.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\02f84a08618da7b25c3461544a09e1968eeb510f.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\09aa310e3635ced1d6c811f804fff456f74cd146.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\0c5be1c585cf2eeba7909b3bf73df61675eb756f.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\13a8e71748efb42d3d99d5a9764db20fb2c3819f.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\1bdee17e1b8d628cb8c641fd9bd574dbaf9e7d51.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x82 in position 7: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\1e7427f45d944785d9c390c6e7e4e0a9327c1802.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\26eb4a6b6ee0c81d0006abdd458220b10b575297.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\28b1f2ad381e5f44d7a0d7d46facf863091d6901.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\2d435fe99783b85c7c973121e84bd553ab8a2f7f.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\2ded0a9c36e581c9c5548d0e19afece17b03b299.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\2e3acc8c2008ae548a0854d781d996f7de039b45.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x82 in position 7: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3188d3a89fbbf01193e25ede761f12463cbd6759.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3347cfe905cdbd9ce1edcac97f98a81f06802461.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3464e09e94112475fbd3800756a2fe7f611d88e2.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\346ed904be5384689453da524d6f686d0f38cf73.txt
# Error decoding file: 'utf-8' codec can't decode byte 0xcb in position 37: invalid continuation byte : E:/vmshared_storage/Kali202004/bin2text\txt\34db67d9945347a94c193030f847efd167d206fa.txt
# Error decoding file: 'utf-8' codec can't decode byte 0xfe in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3748f0bffd13bcda24a2a5676a27df36132148ad.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x82 in position 7: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\37e345a10ab2654e895894763b6d267b410894c2.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3b4b37c79e796b6344edb728127b349580c0603a.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3cb2fcaad610fd9a251b8b209e57e455f177d26e.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3cee91cbdf10a21293e7234fa43c373bcb75da2b.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\3d27b72692e344e6040528684784ecb495ae6b76.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\41bbc8e79791a24aefd64e4b86736b906278a837.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\438e36e9fb1b96718ddecc420ffe64ddeae21401.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\444e52586f03d17b3047ea22241293dd556373f5.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\44dd83718c70626bbfabac5d0fd3e3651fe20319.txt
# Error decoding file: 'utf-8' codec can't decode byte 0xea in position 37: invalid continuation byte : E:/vmshared_storage/Kali202004/bin2text\txt\4529e104f4f3e68513a026ed83876afd4eab426d.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt
txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\e93f768da6f6e3d780c76b43c679f20131aa5fe6.txt
# Error decoding file: 'utf-8' codec can't decode byte 0xab in position 45: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\ea052a565617d0b1e7b7948bb36dfce379fd2660.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\eb8e59c586929fee88b8e1b4df173644c33376ec.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\ecf0fde409da890fe9c1d4da7ac9ae32caf0284a.txt
# Error decoding file: 'utf-8' codec can't decode byte 0xab in position 45: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\efb111bb8b55d872ed70dc63bea40f4408819dc9.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\efbae426ca317aaf971d89f4051502acd3693de1.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\f03bd9a8d4339bb6e75e0b480d2eac3be0fd925e.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\f074a8f92bfac27653b97b89b2db642cf9d87764.txt
# Error decoding file: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte : E:/vmshared_storage/Kali202004/bin2text\txt\fd5cfb8c3154617d0d0047b5e3d08573c26469b1.txt
# Computing time: 23652.29 seconds
# The results are saved to a default folder ./output/xu_simple_E-vmshared_storage-Kali202004-bin2text-ip_2023-03-22_18-55-09.csv
#      type          value  start_pos  end_pos  \
# 0      ip  1.000.000.000        9.0     21.0
# 1      ip        1.0.0.1        6.0     12.0
# 2      ip        1.0.0.1        9.0     15.0
# 3      ip        1.1.1.1        6.0     12.0
# 4      ip        1.1.1.1        9.0     15.0
# ...   ...            ...        ...      ...
# 6750   ip        3.4.2.1       20.0     26.0
# 6751   ip        3.4.2.1       20.0     26.0
# 6752   ip    100.0.33.17       35.0     45.0
# 6753   ip    10.160.94.3        2.0     12.0
# 6754   ip   172.16.1.133        2.0     13.0
#
#                                                 file_id  \
# 0     E:/vmshared_storage/Kali202004/bin2text\Apple_...
# 1     E:/vmshared_storage/Kali202004/bin2text\Apple_...
# 2     E:/vmshared_storage/Kali202004/bin2text\Apple_...
# 3     E:/vmshared_storage/Kali202004/bin2text\Apple_...
# 4     E:/vmshared_storage/Kali202004/bin2text\Apple_...
# ...                                                 ...
# 6750  E:/vmshared_storage/Kali202004/bin2text\txt\3e...
# 6751  E:/vmshared_storage/Kali202004/bin2text\txt\3e...
# 6752  E:/vmshared_storage/Kali202004/bin2text\txt\e7...
# 6753  E:/vmshared_storage/Kali202004/bin2text\txt\e8...
# 6754  E:/vmshared_storage/Kali202004/bin2text\txt\e8...
#
#                                                  text  line_num
# 0                   \t<string>1.000.000.000+</string>        77
# 1                                \t<key>1.0.0.1</key>      4612
# 2                          \t<string>1.0.0.1</string>      4613
# 3                                \t<key>1.1.1.1</key>      4616
# 4                          \t<string>1.1.1.1</string>      4617
# ...                                               ...       ...
# 6750                    SCP Ver.......... 3.4.2.1.6.0        22
# 6751                    SCP Ver.......... 3.4.2.1.6.0        41
# 6752  Apple clang version 11.0.0 (clang-1100.0.33.17)        40
# 6753                # 10.160.94.3\tasecretkeygoeshere         1
# 6754               # 172.16.1.133\tasecretkeygoeshere         2
#
# [6755 rows x 7 columns]
